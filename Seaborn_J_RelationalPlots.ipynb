# %% [markdown]
# RELATIONAL PLOTS

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
sns.set()

# %%
tips = sns.load_dataset("tips")

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# RELPLOT

# %%
sns.relplot(x="total_bill", y="tip", data=tips, kind="line")
plt.savefig("img_1")

# %%
ins = pd.read_csv("F:\Data Science Course\Joyita\insurance.csv")

# %%
ins.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
sns.relplot(x="age", y="charges", data = ins)

# %%
sns.relplot(x="age", y="charges", data = ins, hue="sex")

# %%
sns.relplot(x="age", y="bmi", data = ins)

# %%
sns.relplot(x="age", y="bmi", data = ins, hue="sex")

# %%
sns.relplot(x="age", y="charges", data = ins, hue="children")

# %%
sns.relplot(x="age", y="charges", data = ins, style="smoker")

# %%
sns.relplot(x="age", y="charges", data = ins, style="children", hue="smoker")

# %%
sns.relplot(x="age", y="charges", data = ins, hue="region")

# %%
sns.relplot(x="age", y="charges", data = ins, style="region", hue="sex")

# %%
sns.relplot(x="age", y="charges", data = ins, col="children")

# %%
sns.relplot(x="age", y="charges", data = ins, col="children", col_wrap=3)

# %%
sns.relplot(x="age", y="charges", data = ins, hue="sex", col="children", col_wrap=3)

# %%
sns.relplot(x="age", y="charges", data = ins, hue="smoker", col="children", col_wrap=3)

# %%
sns.relplot(x="age", y="charges", data = ins, col="region")

# %%
sns.relplot(x="age", y="charges", data = ins, hue="children", palette= 'ch:r=0.5, l=0.75')

# %%
sns.relplot(x="age", y="charges", data = ins, size="children", sizes=(1,100))

# %%
sns.relplot(x="age", y="charges", data = ins, kind="line")

# %%
sns.relplot(x="age", y="charges", data = ins, kind="line", hue="smoker")

# %%
sns.relplot(x="age", y="charges", data = ins, kind="line", hue="smoker", style="children")

# %%
sns.relplot(x="children", y="charges", data = ins, kind="line", hue="smoker")

# %%
sns.relplot(x="age", y="charges", data=ins, kind="line", ci=False)

# %%
sns.relplot(x="age", y="charges", data=ins, kind="line", ci="sd")

# %%
sns.relplot(x="age", y="charges", data=ins, kind="line", estimator=None)

# %%
sns.relplot(x="age", y="charges", data=ins, kind="line", markers = True)

# %% [markdown]
# LINEPLOT

# %%
fmri = sns.load_dataset("fmri")
fmri.head()
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970

# %%
sns.lineplot(x="age", y="charges", data=ins)

# %%
sns.lineplot(x="age", y="charges", data=ins, ci = None)

# %%
sns.lineplot(x="age", y="charges", data=ins, ci="sd")

# %%
sns.lineplot(x="age", y="charges", data=ins, estimator=None)

# %%
sns.lineplot(x="age", y="charges", data=ins, markers = True)

# %%
sns.lineplot(x="age", y="charges", data=ins, markers = True, ci = 50)

# %%
sns.lineplot(x="age", y="charges", data=ins, markers = True, ci = 50, err_style="bars")

# %% [markdown]
# SCATTERPLOT

# %%
sns.scatterplot(x="age", y="charges", data=ins)

# %%
sns.scatterplot(x="age", y="charges", data=ins, hue="smoker")

# %%
sns.scatterplot(x="age", y="charges", data=ins, hue="sex")

# %%
sns.scatterplot(x="age", y="charges", data=ins, hue="smoker", size="children")

# %%
sns.scatterplot(x="age", y="charges", data=ins, hue="smoker", size="children", style="sex")

# %%
sns.scatterplot(x="age", y="charges", data=ins, hue="smoker", size="children", style="region")

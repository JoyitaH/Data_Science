# %%
import pandas as pd

# %%
data = pd.read_csv("F:\Data Science Course\Joyita\insurance.csv")

# %%
data
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
data.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
data.head(10)
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520
# 5   31  female  25.740         0     no  southeast   3756.62160
# 6   46  female  33.440         1     no  southeast   8240.58960
# 7   37  female  27.740         3     no  northwest   7281.50560
# 8   37    male  29.830         2     no  northeast   6406.41070
# 9   60  female  25.840         0     no  northwest  28923.13692

# %%
data.tail()
# Out:
#       age     sex    bmi  children smoker     region     charges
# 1333   50    male  30.97         3     no  northwest  10600.5483
# 1334   18  female  31.92         0     no  northeast   2205.9808
# 1335   18  female  36.85         0     no  southeast   1629.8335
# 1336   21  female  25.80         0     no  southwest   2007.9450
# 1337   61  female  29.07         0    yes  northwest  29141.3603

# %%
data.tail(3)
# Out:
#       age     sex    bmi  children smoker     region     charges
# 1335   18  female  36.85         0     no  southeast   1629.8335
# 1336   21  female  25.80         0     no  southwest   2007.9450
# 1337   61  female  29.07         0    yes  northwest  29141.3603

# %%
data = pd.read_csv("F:\Data Science Course\Joyita\insurance.csv", nrows=10)
data
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520
# 5   31  female  25.740         0     no  southeast   3756.62160
# 6   46  female  33.440         1     no  southeast   8240.58960
# 7   37  female  27.740         3     no  northwest   7281.50560
# 8   37    male  29.830         2     no  northeast   6406.41070
# 9   60  female  25.840         0     no  northwest  28923.13692

# %%
data = pd.read_csv("F:\Data Science Course\Joyita\insurance.csv")

# %%
data
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
data.dtypes
# Out:
# age           int64
# sex          object
# bmi         float64
# children      int64
# smoker       object
# region       object
# charges     float64
# dtype: object

# %%
data['age']
# Out:
# 0       19
# 1       18
# 2       28
# 3       33
# 4       32
#         ..
# 1333    50
# 1334    18
# 1335    18
# 1336    21
# 1337    61
# Name: age, Length: 1338, dtype: int64

# %%
list(data['age'])
# Out:
# [19,
#  18,
#  28,
#  33,
#  32,
#  31,
#  46,
#  37,
#  37,
#  60,
#  25,
#  62,
#  23,
#  56,
#  27,
#  19,
#  52,
#  23,
#  56,
#  30,
#  60,
#  30,
#  18,
#  34,
#  37,
#  59,
#  63,
#  55,
#  23,
#  31,
#  22,
#  18,
#  19,
#  63,
#  28,
#  19,
#  62,
#  26,
#  35,
#  60,
#  24,
#  31,
#  41,
#  37,
#  38,
#  55,
#  18,
#  28,
#  60,
#  36,
#  18,
#  21,
#  48,
#  36,
#  40,
#  58,
#  58,
#  18,
#  53,
#  34,
#  43,
#  25,
#  64,
#  28,
#  20,
#  19,
#  61,
#  40,
#  40,
#  28,
#  27,
#  31,
#  53,
#  58,
#  44,
#  57,
#  29,
#  21,
#  22,
#  41,
#  31,
#  45,
#  22,
#  48,
#  37,
#  45,
#  57,
#  56,
#  46,
#  55,
#  21,
#  53,
#  59,
#  35,
#  64,
#  28,
#  54,
#  55,
#  56,
#  38,
#  41,
#  30,
#  18,
#  61,
#  34,
#  20,
#  19,
#  26,
#  29,
#  63,
#  54,
#  55,
#  37,
#  21,
#  52,
#  60,
#  58,
#  29,
#  49,
#  37,
#  44,
#  18,
#  20,
#  44,
#  47,
#  26,
#  19,
#  52,
#  32,
#  38,
#  59,
#  61,
#  53,
#  19,
#  20,
#  22,
#  19,
#  22,
#  54,
#  22,
#  34,
#  26,
# ...

# %%
type(data['age'])
# Out:
# pandas.core.series.Series

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data['charges'][7]
# Out:
# 7281.5056

# %%
data[['age']]
# Out:
#       age
# 0      19
# 1      18
# 2      28
# 3      33
# 4      32
# ...   ...
# 1333   50
# 1334   18
# 1335   18
# 1336   21
# 1337   61
#
# [1338 rows x 1 columns]

# %%
print(type(data[['age']]))
print(type(data['age']))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.series.Series'>

# %%
data[['age','sex','charges']]
# Out:
#       age     sex      charges
# 0      19  female  16884.92400
# 1      18    male   1725.55230
# 2      28    male   4449.46200
# 3      33    male  21984.47061
# 4      32    male   3866.85520
# ...   ...     ...          ...
# 1333   50    male  10600.54830
# 1334   18  female   2205.98080
# 1335   18  female   1629.83350
# 1336   21  female   2007.94500
# 1337   61  female  29141.36030
#
# [1338 rows x 3 columns]

# %%
pd.read_csv("F:\Data Science Course\Joyita\insurance.csv", nrows=10)
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520
# 5   31  female  25.740         0     no  southeast   3756.62160
# 6   46  female  33.440         1     no  southeast   8240.58960
# 7   37  female  27.740         3     no  northwest   7281.50560
# 8   37    male  29.830         2     no  northeast   6406.41070
# 9   60  female  25.840         0     no  northwest  28923.13692

# %%
data = pd.read_csv("F:\Data Science Course\Joyita\insurance.csv", nrows=10,header=None)

# %%
data
# Out:
#      0       1       2         3       4          5            6
# 0  age     sex     bmi  children  smoker     region      charges
# 1   19  female    27.9         0     yes  southwest    16884.924
# 2   18    male   33.77         1      no  southeast    1725.5523
# 3   28    male      33         3      no  southeast     4449.462
# 4   33    male  22.705         0      no  northwest  21984.47061
# 5   32    male   28.88         0      no  northwest    3866.8552
# 6   31  female   25.74         0      no  southeast    3756.6216
# 7   46  female   33.44         1      no  southeast    8240.5896
# 8   37  female   27.74         3      no  northwest    7281.5056
# 9   37    male   29.83         2      no  northeast    6406.4107

# %%
data[0]
# Out:
# 0    age
# 1     19
# 2     18
# 3     28
# 4     33
# 5     32
# 6     31
# 7     46
# 8     37
# 9     37
# Name: 0, dtype: object

# %%
a = pd.read_csv("F:\Data Science Course\Joyita\insurance.csv", nrows=10, header=None, skiprows=3)

# %%
a
# Out:
#     0       1       2  3    4          5            6
# 0  28    male  33.000  3   no  southeast   4449.46200
# 1  33    male  22.705  0   no  northwest  21984.47061
# 2  32    male  28.880  0   no  northwest   3866.85520
# 3  31  female  25.740  0   no  southeast   3756.62160
# 4  46  female  33.440  1   no  southeast   8240.58960
# 5  37  female  27.740  3   no  northwest   7281.50560
# 6  37    male  29.830  2   no  northeast   6406.41070
# 7  60  female  25.840  0   no  northwest  28923.13692
# 8  25    male  26.220  0   no  northeast   2721.32080
# 9  62  female  26.290  0  yes  southeast  27808.72510

# %%
a = pd.read_csv("F:\Data Science Course\Joyita\insurance.csv", nrows=10, header=None, skiprows=[3])

# %%
a
# Out:
#      0       1       2         3       4          5            6
# 0  age     sex     bmi  children  smoker     region      charges
# 1   19  female    27.9         0     yes  southwest    16884.924
# 2   18    male   33.77         1      no  southeast    1725.5523
# 3   33    male  22.705         0      no  northwest  21984.47061
# 4   32    male   28.88         0      no  northwest    3866.8552
# 5   31  female   25.74         0      no  southeast    3756.6216
# 6   46  female   33.44         1      no  southeast    8240.5896
# 7   37  female   27.74         3      no  northwest    7281.5056
# 8   37    male   29.83         2      no  northeast    6406.4107
# 9   60  female   25.84         0      no  northwest  28923.13692

# %%
a = pd.read_csv("F:\Data Science Course\Joyita\insurance.csv", nrows=10, header=None, names= ['a','b','c','d','e','f','g'])

# %%
a
# Out:
#      a       b       c         d       e          f            g
# 0  age     sex     bmi  children  smoker     region      charges
# 1   19  female    27.9         0     yes  southwest    16884.924
# 2   18    male   33.77         1      no  southeast    1725.5523
# 3   28    male      33         3      no  southeast     4449.462
# 4   33    male  22.705         0      no  northwest  21984.47061
# 5   32    male   28.88         0      no  northwest    3866.8552
# 6   31  female   25.74         0      no  southeast    3756.6216
# 7   46  female   33.44         1      no  southeast    8240.5896
# 8   37  female   27.74         3      no  northwest    7281.5056
# 9   37    male   29.83         2      no  northeast    6406.4107

# %%
a = pd.read_csv("F:\Data Science Course\Joyita\insurance.csv", nrows=10, header=None, names= ['a','b','c','d'])

# %%
a
# Out:
#                           a       b          c            d
# age sex    bmi     children  smoker     region      charges
# 19  female 27.9           0     yes  southwest    16884.924
# 18  male   33.77          1      no  southeast    1725.5523
# 28  male   33             3      no  southeast     4449.462
# 33  male   22.705         0      no  northwest  21984.47061
# 32  male   28.88          0      no  northwest    3866.8552
# 31  female 25.74          0      no  southeast    3756.6216
# 46  female 33.44          1      no  southeast    8240.5896
# 37  female 27.74          3      no  northwest    7281.5056
#     male   29.83          2      no  northeast    6406.4107

# %%
a = pd.read_csv("F:\Data Science Course\Joyita\insurance.csv", nrows=10, header=None, names= ['a','b','c','d','e','f','g','h'])

# %%
a
# Out:
#      a       b       c         d       e          f            g   h
# 0  age     sex     bmi  children  smoker     region      charges NaN
# 1   19  female    27.9         0     yes  southwest    16884.924 NaN
# 2   18    male   33.77         1      no  southeast    1725.5523 NaN
# 3   28    male      33         3      no  southeast     4449.462 NaN
# 4   33    male  22.705         0      no  northwest  21984.47061 NaN
# 5   32    male   28.88         0      no  northwest    3866.8552 NaN
# 6   31  female   25.74         0      no  southeast    3756.6216 NaN
# 7   46  female   33.44         1      no  southeast    8240.5896 NaN
# 8   37  female   27.74         3      no  northwest    7281.5056 NaN
# 9   37    male   29.83         2      no  northeast    6406.4107 NaN

# %%
data = pd.read_csv("F:\Data Science Course\Joyita\insurance.csv", index_col= ["region"])

# %%
data
# Out:
#            age     sex     bmi  children smoker      charges
# region
# southwest   19  female  27.900         0    yes  16884.92400
# southeast   18    male  33.770         1     no   1725.55230
# southeast   28    male  33.000         3     no   4449.46200
# northwest   33    male  22.705         0     no  21984.47061
# northwest   32    male  28.880         0     no   3866.85520
# ...        ...     ...     ...       ...    ...          ...
# northwest   50    male  30.970         3     no  10600.54830
# northeast   18  female  31.920         0     no   2205.98080
# southeast   18  female  36.850         0     no   1629.83350
# southwest   21  female  25.800         0     no   2007.94500
# northwest   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %% [markdown]
# CATEGORICAL PLOTS

# %% [markdown]
# CATPLOT

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
ins = pd.read_csv("F:\Data Science Course\Joyita\insurance.csv")
ins.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
sns.catplot(x="age", y="charges", data=ins)

# %%
sns.catplot(x="region", y="charges", data=ins)

# %%
sns.catplot(y="region", x="charges", data=ins)

# %%
sns.catplot(x="children", y="charges", data=ins)

# %%
sns.catplot(x="children", y="charges", data=ins, jitter=False)

# %%
sns.catplot(x="children", y="charges", data=ins, kind="swarm")

# %%
sns.catplot(x="children", y="charges", data=ins, kind="swarm", hue="smoker")

# %%
sns.catplot(x="children", y="charges", data=ins, kind="swarm", hue="sex")

# %%
sns.catplot(x="sex", y="charges", data=ins)

# %%
sns.catplot(x="smoker", y="age", data=ins)

# %%
sns.catplot(x="sex", y="bmi", data=ins)

# %%
sns.catplot(x="smoker", y="charges", data=ins)

# %%
sns.catplot(x="smoker", y="charges", data=ins, order=["no","yes"])

# %%
sns.catplot(x="smoker", y="charges", data=ins, kind="box")

# %%
sns.catplot(x="children", y="charges", data=ins, kind="box")

# %%
sns.catplot(x="children", y="charges", data=ins, kind="box", hue="smoker")

# %%
sns.catplot(x="children", y="charges", data=ins, kind="box", hue="sex")

# %%
sns.catplot(x="children", y="charges", data=ins, kind="box", hue="smoker", dodge=False)

# %%
sns.catplot(x="children", y="charges", data=ins, kind="box", hue="sex", dodge=False)

# %%
sns.catplot(x="children", y="charges", data=ins, kind="boxen")

# %%
sns.catplot(x="region", y="charges", kind="boxen", data=ins)

# %%
sns.catplot(x="region", y="charges", kind="boxen", data=ins.sort_values("region"))

# %%
sns.catplot(x="children", y="charges", data=ins, kind="boxen", hue="smoker")

# %%
sns.catplot(x="children", y="charges", data=ins, kind="boxen", hue="sex")

# %%
sns.catplot(x="children", y="charges", data=ins, kind="boxen", hue="sex", dodge=False)

# %%
sns.catplot(x="region", y="charges", data=ins, kind="violin")

# %%
sns.catplot(x="children", y="charges", data=ins, kind="violin")

# %%
sns.catplot(x="children", y="charges", data=ins, kind="violin", hue="smoker")

# %%
sns.catplot(x="children", y="charges", data=ins, kind="violin", hue="sex")

# %%
sns.catplot(x="children", y="charges", data=ins, kind="violin", hue="sex", split=True)

# %%
sns.catplot(x="children", y="charges", data=ins, kind="violin", hue="sex", split=True, inner="stick")

# %%
sns.catplot(x="smoker", y="charges", data=ins, kind="bar")

# %%
sns.catplot(x="children", y="charges", data=ins, kind="bar", hue="smoker")

# %%
sns.catplot(x="region", data=ins, kind="count")

# %%
sns.catplot(x="children", data=ins, kind="count")

# %%
sns.catplot(x="children", data=ins, kind="count", hue="sex")

# %%
sns.catplot(x="children", data=ins, kind="count", hue="smoker")

# %%
sns.catplot(x="smoker", y="children", data=ins, kind="point", hue="sex")

# %% [markdown]
# BOXPLOT

# %%
sns.set(style="whitegrid")
sns.boxplot(x = ins["charges"])

# %%
sns.set(style="darkgrid")
sns.boxplot(x = ins["charges"])

# %%
sns.boxplot(x="children", y="charges", data=ins)

# %%
sns.boxplot(x="children", y="charges", data=ins, hue="smoker")

# %%
sns.boxplot(x="children", y="charges", data=ins, hue="smoker", palette="Accent_r")

# %%
sns.boxplot(x="children", y="charges", data=ins, hue="smoker", palette="Accent_r",linewidth=3)

# %%
sns.boxplot(x="sex", y="charges", data=ins, hue="smoker")

# %%
sns.boxplot(x="sex", y="charges", data=ins, hue="smoker", order=["male", "female"])

# %%
sns.boxplot(data=ins, orient="h")

# %%
#Boxplot with Swarmplot
sns.boxplot(x="children", y="charges", data=ins)
sns.swarmplot(x="children", y="charges", data=ins, color=".25")

# %% [markdown]
# BOXENPLOT

# %%
sns.boxenplot(data=ins, x="charges")

# %%
sns.boxenplot(data=ins, y="charges")

# %%
sns.boxenplot(data=ins, x="bmi")

# %%
sns.boxenplot(x="children", y="charges", data=ins)

# %%
sns.boxenplot(x="children", y="charges", data=ins, palette="Set2")

# %%
sns.boxenplot(x="children", y="charges", data=ins, palette="Set2", linewidth=5)

# %%
sns.boxenplot(x="children", y="charges", data=ins, palette="Set1", hue="smoker")

# %% [markdown]
# SWARMPLOT

# %%
sns.swarmplot(data=ins, x="charges")

# %%
sns.swarmplot(data=ins, x="bmi")

# %%
sns.swarmplot(data=ins, y="charges")

# %%
sns.swarmplot(data=ins, x="children", y="charges")

# %%
sns.swarmplot(data=ins, x="children", y="charges", hue="smoker")

# %%
sns.swarmplot(data=ins, x="children", y="charges", hue="smoker", dodge=True)

# %%
sns.swarmplot(data=ins, x="children", y="charges", hue="sex", dodge=True)

# %%
sns.swarmplot(data=ins, x="children", y="charges", hue="smoker", dodge=True, size=7)

# %%
#Swarmplot with Boxplot
sns.boxplot(data=ins, x="children", y="charges", whis=np.inf)
sns.swarmplot(data=ins, x="children", y="charges", color=".4")

# %%
sns.boxplot(data=ins, x="children", y="charges")
sns.swarmplot(data=ins, x="children", y="charges", color=".3")

# %%
#Swarmplot with Violinplot
sns.violinplot(data=ins, x="children", y="charges", inner=None)
sns.swarmplot(data=ins, x="children", y="charges", color="yellow", edgecolor="black")

# %%
sns.violinplot(data=ins, x="children", y="charges")
sns.swarmplot(data=ins, x="children", y="charges", color="pink", edgecolor="black")

# %% [markdown]
# BARPLOT

# %%
sns.barplot(x="children", y="charges", data=ins, hue="smoker")

# %%
sns.barplot(x="smoker", y="charges", data=ins)

# %%
sns.barplot(x="smoker", y="charges", data=ins, ci=90)

# %%
sns.barplot(x="smoker", y="charges", data=ins, ci="sd")

# %% [markdown]
# STRIPPLOT

# %%
sns.stripplot(data=ins, x="children", y="charges")

# %% [markdown]
# DISTPLOT

# %%
sns.set(style="whitegrid")
sns.distplot(ins["charges"])

# %%
sns.distplot(ins["charges"], hist=False)

# %%
sns.distplot(ins["charges"], hist=False, rug=True)

# %%
sns.distplot(ins["charges"], kde=False)

# %%
sns.distplot(ins["charges"], vertical=True)

# %%
sns.set_color_codes()
sns.distplot(ins["bmi"], color="m")

# %%
sns.distplot(ins["charges"], color="y", norm_hist=True)

# %%
from scipy.stats import norm
sns.distplot(ins["charges"], color="r", fit=norm, kde=False)

# %% [markdown]
# KDEPLOT

# %%
sns.kdeplot(ins["charges"])

# %%
sns.kdeplot(ins["bmi"])

# %%
sns.kdeplot(ins["charges"], shade=True)

# %%
sns.kdeplot(ins["charges"], shade=True, color="g")

# %%
sns.kdeplot(ins["age"], ins["charges"])

# %%
sns.kdeplot(ins["age"], ins["charges"], shade=True)

# %% [markdown]
# HEATMAP

# %%
flights = sns.load_dataset("flights")
flights.head()
# Out:
#    year     month  passengers
# 0  1949   January         112
# 1  1949  February         118
# 2  1949     March         132
# 3  1949     April         129
# 4  1949       May         121

# %%
flights = flights.pivot("month", "year", "passengers")
a = sns.heatmap(flights)

# %%
sns.heatmap(flights, annot=True, fmt="d")

# %%
sns.heatmap(flights, annot=True, fmt="d", cmap="YlGnBu")

# %%
sns.heatmap(flights, annot=True, fmt="d", cmap="YlGnBu", cbar=False)

# %% [markdown]
# OTHER PLOTS

# %%
sns.pairplot(data=ins)

# %%
sns.regplot(data=ins, x="bmi", y="charges")

# %%
sns.lmplot(data=ins, x="bmi", y="charges")

# %%
sns.regplot(data=ins, x="bmi", y="charges", order=4)

# %%
sns.regplot(data=ins, x="bmi", y="charges", robust=True)

# %%
sns.lmplot(data=ins, x="bmi", y="charges", robust=True, hue="smoker")
